# %% [markdown]
# ## Desempleo con brecha de género
#
# #### Ken Luzuriaga - Luis Rodriguez - Nicole Vera - Freya Lopez - Anthony Galarza

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Importar dataset resultante del Procesamiento y limpieza de indicadores del Banco Mundial

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/proyecto/ResultDatasset.csv")

# %%
df.sample(5)
# Out:
#                 Country Name Country Code  Year  SL.UEM.TOTL.FE.ZS  \
# 13745           Sierra Leona          SLE  2003              2.323
# 7744   Islas Turcas y Caicos          TCA  2016              0.000
# 11969                   Perú          PER  1963              0.000
# 12246            Puerto Rico          PRI  1992             13.279
# 10843        Nueva Caledonia          NCL  2015             14.836
#
#        SL.UEM.TOTL.MA.NE.ZS  SL.UEM.ADVN.ZS
# 13745                  4.84             0.0
# 7744                   0.00             0.0
# 11969                  0.00             0.0
# 12246                 19.09             0.0
# 10843                  0.00             0.0

# %% [markdown]
# Ahora realizamos la matriz de co ocurrencias.

# %%
mcor = df.corr()
sb.set(rc={'figure.figsize':(10,5)})
mcplot = sb.heatmap(mcor, cmap='YlGnBu', annot=True, linewidths=0.4, annot_kws={"size":10})

# %%
mcor = mcor[((mcor >= 0.2) | (mcor<= -0.2)) & (mcor!=1.0)]
mcplot = sb.heatmap(mcor, cmap='YlGnBu', annot=True, linewidths=0.4, annot_kws={"size":10})

# %%
df.boxplot(vert=False, column=['SL.UEM.TOTL.FE.ZS'], figsize=(7,7))
# Out:
# <AxesSubplot:>

# %%
df['SL.UEM.TOTL.FE.ZS'].hist() #SL.UEM.TOTL.MA.NE.ZS	SL.UEM.ADVN.ZS
# Out:
# <AxesSubplot:>

# %%
df.boxplot(vert=False, column=['SL.UEM.TOTL.FE.ZS'], figsize=(10,7))
# Out:
# <AxesSubplot:>

# %%
df['SL.UEM.TOTL.MA.NE.ZS'].hist()
# Out:
# <AxesSubplot:>

# %%
df.boxplot(vert=False, column=['SL.UEM.ADVN.ZS'], figsize=(10,7))
# Out:
# <AxesSubplot:>

# %%
df['SL.UEM.ADVN.ZS'].hist()
# Out:
# <AxesSubplot:>

# %%
dfp = df.apply(lambda row: row[df['Country Code'].isin(['CAN','ECU','CZE'])])

dfp.boxplot(vert=False, column=['SL.UEM.TOTL.MA.NE.ZS'], figsize=(10,7), by="Country Name")
# Out:
# <AxesSubplot:title={'center':'SL.UEM.TOTL.MA.NE.ZS'}, xlabel='Country Name'>

# %%
dfc = df.apply(lambda row: row[df['Country Code'].isin(['CAN','ECU','CZE'])])

dfc.boxplot(vert=False, column=['SL.UEM.TOTL.MA.NE.ZS'], figsize=(10,7), by="Country Name")
# Out:
# <AxesSubplot:title={'center':'SL.UEM.TOTL.MA.NE.ZS'}, xlabel='Country Name'>

# %%
dfc = df.apply(lambda row: row[df['Country Code'].isin(['CAN','ECU','CZE'])])

dfc.boxplot(vert=False, column=['SL.UEM.ADVN.ZS'], figsize=(10,7), by="Country Name")
# Out:
# <AxesSubplot:title={'center':'SL.UEM.ADVN.ZS'}, xlabel='Country Name'>

# %% [markdown]
# **Conclusion:** Podemos concluir que almenos en Ecuador, con comparacion de otros paises angloparlante, el desempleo de hombres y mujeres se ve reflejado en mediana medida por el nivel de educacion que concluye cada individuo.
